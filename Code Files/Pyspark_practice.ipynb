# %%
import pyspark

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("Practice").getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[2], line 3
#       1 from pyspark.sql import SparkSession
# ----> 3 spark = SparkSession.builder.appName("Practice").getOrCreate()
#
# File c:\Users\User\anaconda3\lib\site-packages\pyspark\sql\session.py:228, in SparkSession.Builder.getOrCreate(self)
#     226         sparkConf.set(key, value)
#     227     # This SparkContext may be an existing one.
# --> 228     sc = SparkContext.getOrCreate(sparkConf)
#     229 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     230 # by all sessions.
#     231 session = SparkSession(sc)
#
# File c:\Users\User\anaconda3\lib\site-packages\pyspark\context.py:392, in SparkContext.getOrCreate(cls, conf)
#     390 with SparkContext._lock:
#     391     if SparkContext._active_spark_context is None:
# --> 392         SparkContext(conf=conf or SparkConf())
# ...
